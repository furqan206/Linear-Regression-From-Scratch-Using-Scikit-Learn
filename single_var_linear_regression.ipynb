# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel("homesales.xlsx")
df
# Out:
#     area        prices
# 0   1000  3.283010e+05
# 1   1500  4.288493e+06
# 2   2300  5.897260e+05
# 3   3540  8.390840e+05
# 4   4120  9.557200e+05
# 5   4560  1.044202e+06
# 6   5490  1.231221e+06
# 7   3460  8.229970e+05
# 8   4750  1.082410e+06
# 9   2300  5.897260e+05
# 10  9000  1.937068e+06
# 11  8600  1.856630e+06
# 12  7100  1.554986e+06

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area, df.prices, color='black',marker='*')
plt.plot(df.area, reg.predict(df[['area']]), color = "red")
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3320]])
# Out:
# C:\Users\Home\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([794843.83561644])

# %%
reg.coef_
# Out:
# array([201.09589041])

# %%
d = pd.read_excel('area.xlsx')
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(d)

# %%
d['prices'] = p

# %%
d.to_excel("homesales.xlsx", index=False)
